# %% [markdown]
# Up until now, we have been the Client (sending requests). Now, we are going to build the Server (receiving requests).
#
# FastAPI is the industry standard for AI backends because it natively supports the async concepts we just learned, and it pairs perfectly with Pydantic, which acts like a strict bouncer for your data.
#
# FYI: We can't run the code in a notebook because it will freeze the notebook, check fastapi_and_pydantic.py!

# %% [markdown]
# Core packages:
# 1. FastAPI: The web framework itself.
# 2. Uvicorn: The lightning-fast asynchronous server that actually runs your FastAPI code (it acts as the middleman between the internet and your Python code).
# 3. Pydantic: The data validation library.

# %%
pip install fastapi "uvicorn[standard]" pydantic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fastapi
#   Downloading fastapi-0.128.8-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 13.0 MB/s eta 0:00:01
# Collecting uvicorn[standard]
#   Downloading uvicorn-0.39.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 26.1 MB/s eta 0:00:01
# Collecting pydantic
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 50.8 MB/s eta 0:00:01
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from fastapi) (4.15.0)
# Collecting starlette<1.0.0,>=0.40.0
#   Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 4.1 MB/s eta 0:00:011
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: h11>=0.8 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]) (0.16.0)
# Requirement already satisfied: click>=7.0 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]) (8.1.8)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.1.1-cp39-cp39-macosx_11_0_arm64.whl (396 kB)
#      |████████████████████████████████| 396 kB 46.9 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml>=5.1 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]) (6.0.3)
# Collecting uvloop>=0.15.1
#   Downloading uvloop-0.22.1-cp39-cp39-macosx_10_9_universal2.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 55.4 MB/s eta 0:00:01
# Collecting httptools>=0.6.3
#   Downloading httptools-0.7.1-cp39-cp39-macosx_11_0_arm64.whl (110 kB)
#      |████████████████████████████████| 110 kB 25.6 MB/s eta 0:00:01
# Requirement already satisfied: websockets>=10.4 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from uvicorn[standard]) (15.0.1)
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_11_0_arm64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 21.6 MB/s eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from starlette<1.0.0,>=0.40.0->fastapi) (4.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<1.0.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/pierson.chu/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<1.0.0,>=0.40.0->fastapi) (3.11)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, watchfiles, uvloop, uvicorn, starlette, python-dotenv, pydantic, httptools, annotated-doc, fastapi
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 fastapi-0.128.8 httptools-0.7.1 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.1 starlette-0.49.3 typing-inspection-0.4.2 uvicorn-0.39.0 uvloop-0.22.1 watchfiles-1.1.1
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# to run the actual server you need to do the following:
# 1. uvicorn fastapi_and_pydantic:app --reload
# 2. go to the web address it says it is running on
#
# Breaking down the command:
# * uvicorn: The server program.
# * fastapi_and_pydantic: The name of your Python file (notice there is no .py).
# * :: The separator telling Uvicorn to look inside that file.
# * app: The name of the variable where you initialized your FastAPI server (app = FastAPI(...)).
# * --reload: The flag that restarts the server whenever you save the file.
#
# FastAPI automatically builds a testing interface for you.
# * Open your web browser and go to: http://localhost:8000/docs
# * You will see a "Swagger UI" dashboard.
# * Click on the green POST /generate bar, click "Try it out", modify the JSON payload it gives you, and hit "Execute".
